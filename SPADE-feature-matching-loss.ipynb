# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import conv_layer
from fastai.vision.data import SegmentationLabelList, SegmentationProcessor, SegmentationItemList
from fastai.vision.transform import get_transforms
from fastai.vision.image import open_image, open_mask, Image
from pathlib import Path
from torch import nn
import pdb

from spadedata import SpadeItemList, SpadeLabelList

# %%
import fastai
print(fastai.__file__, fastai.__version__)
# Out:
# D:\Projects\Spade\fastai\__init__.py 1.0.39

# %%
path = Path(r'D:/data/landcover/landcover/')
batch_size = 8

# %%
codes = ['NoData', 'Water', 'Wetlands', 'Tree1', 'Shurbland', 'Lowvegetation', 'Barren', 'Structures', 'Impervious',
       'Roads', 'Tree2', 'Tree3', 'Tree4']

# %%
 def get_y_func(x, ext='tif'):
    return x.parents[1] / 'images' / (x.stem + '.{}'.format(ext))

# %% [markdown]
# ## Data Prep

# %%
src = (SpadeItemList.from_folder(path/'labels', classes=codes)
      .random_split_by_pct(0.0)
      .label_from_func(get_y_func))

# %%
data = (src.transform(get_transforms(), tfm_y=True, size=256)
       .databunch(bs=batch_size))

# %%
data.show_batch(rows=2)

# %% [markdown]
# ## Model Architecture

# %%
from fastai.vision import ImageSegment, PixelShuffle_ICNR
from fastai.layers import NormType
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
from torch.distributions import Normal
import torch

# %% [markdown]
# ### SPADE Block

# %%
## check dimension after conv layer
class SpadeBN(nn.Module):
    def __init__(self, nf):
        super(SpadeBN, self).__init__()

        self.bn = nn.BatchNorm2d(nf, affine=False)
        self.conv0 = conv_layer(1, 128, norm_type=NormType.Spectral)  # hardcoded
        self.conv1 = conv_layer(128, nf, norm_type=NormType.Spectral)
        self.conv2 = conv_layer(128, nf, norm_type=NormType.Spectral)
        
    def forward(self, features, mask):
#         pdb.set_trace()
        size = features.size()[-2:]
        mask = F.interpolate(mask.float(), size=size)
        interim_conv = self.conv0(mask)
        gamma = self.conv1(interim_conv)
        beta = self.conv2(interim_conv)
        return (self.bn(features) * gamma) + beta

# %% [markdown]
# ###  SPADE ResBlock

# %%
class SpadeResBlock(nn.Module):
    def __init__(self, ni, nf):
        super(SpadeResBlock, self).__init__()
        self.spade_bn0 = SpadeBN(ni)
        ## can get away with spectral norm by passing NormType.Spectral
        self.conv0 = conv_layer(ni, nf, use_activ=False, norm_type=NormType.Spectral)
        self.spade_bn1 = SpadeBN(nf)
        self.conv1 = conv_layer(nf, nf, use_activ=False, norm_type=NormType.Spectral)
        self.spade_skip = SpadeBN(ni)
        self.conv_skip = conv_layer(ni, nf, use_activ=False, norm_type=NormType.Spectral, )
        
    def forward(self, features, mask):
        skip_features = self.conv_skip(F.relu(self.spade_skip(features, mask)))
        features = self.conv0(F.relu(self.spade_bn0(features, mask)))
        features = self.conv1(F.relu(self.spade_bn1(features, mask)))
        return skip_features + features

# %% [markdown]
# ### SpadeGenerator

# %%
device_ = torch.device('cuda')

# %%
class UpsamplingNearest2d(nn.Module):
    def forward(self, x):
        return F.interpolate(x, scale_factor=2)

# %%
# nfs = [1024,1024,1024,512,256,128,64] #orig
nfs = [1024,1024,512,256,128,64]
scale = [2] * len(nfs)
input_noise_dim = 256

class SpadeGenerator(nn.Module):
    
    def __init__(self, input_noise_dim=input_noise_dim,
                 nfs=nfs,
                 pixel_shuffle_upsampling=True,
                 batch_size=batch_size,
                 input_image=None):  ## for semantic style, requires different loss functions
        super(SpadeGenerator, self).__init__()
        self.input_noise_dim = input_noise_dim
        self.batch_size = batch_size
        self.linear = nn.Linear(input_noise_dim, 16384)  # hardcoded
        self.spade_upsample_blocks = nn.ModuleList([])
        for i in range(len(nfs)):
            self.spade_upsample_blocks.append(nn.ModuleList([SpadeResBlock(1024 if i == 0 else nfs[i-1], nfs[i]),
                           PixelShuffle_ICNR(nfs[i], nfs[i], scale=2, norm_type=NormType.Spectral) if pixel_shuffle_upsampling else UpsamplingNearest2d()]))
        self.conv_final = conv_layer(nfs[-1], 3, use_activ=False, bias=True, norm_type=None)
    
    def forward(self, mask):
#         pdb.set_trace()
        
#         mask = args[0]
        gaussian_noise = Normal(0,1).sample(torch.Size([mask.size()[0], self.input_noise_dim])).to(device_).detach()
        linear_features = self.linear(gaussian_noise)
        spatial_features = linear_features.view(self.batch_size, 1024, 4, 4) # hardcoded
        for block in self.spade_upsample_blocks:
            spatial_features = block[0](spatial_features, mask)
            spatial_features = block[1](spatial_features)
#         pdb.set_trace()
        return (torch.tanh(self.conv_final(spatial_features)) + 1)/2

# %% [markdown]
# ### generator test

# %%
test_gen = SpadeGenerator().to(device_)

# %%
inp = torch.randn(8,1,256,256).to(device_)

# %%
x, y = next(iter(data.train_dl))

# %%
from fastai.vision import open_mask, ImageSegment

# %%
x.shape
# Out:
# torch.Size([8, 1, 256, 256])

# %%
ImageSegment(x[0])
# Out:
# ImageSegment (1, 256, 256)

# %%
xx = test_gen(x)

# %%
xx
# Out:
# tensor([[[[0.4686, 0.4446, 0.4160,  ..., 0.4054, 0.3843, 0.4212],
#           [0.3669, 0.3183, 0.3042,  ..., 0.3544, 0.3448, 0.3974],
#           [0.3054, 0.2082, 0.1652,  ..., 0.3209, 0.3083, 0.3978],
#           ...,
#           [0.3724, 0.3899, 0.3853,  ..., 0.4446, 0.4324, 0.4483],
#           [0.4333, 0.4690, 0.4860,  ..., 0.5023, 0.4820, 0.4789],
#           [0.5341, 0.5483, 0.5600,  ..., 0.5342, 0.5133, 0.5181]],
#
#          [[0.4131, 0.3766, 0.3453,  ..., 0.4261, 0.4703, 0.5218],
#           [0.4404, 0.5681, 0.5074,  ..., 0.4599, 0.4944, 0.5073],
#           [0.5300, 0.7331, 0.6505,  ..., 0.4946, 0.5118, 0.5114],
#           ...,
#           [0.4799, 0.5437, 0.5608,  ..., 0.4908, 0.4949, 0.4561],
#           [0.4792, 0.5068, 0.5210,  ..., 0.4528, 0.4684, 0.4436],
#           [0.5214, 0.5039, 0.4790,  ..., 0.4671, 0.4660, 0.4571]],
#
#          [[0.5812, 0.6930, 0.7226,  ..., 0.4453, 0.4401, 0.4274],
#           [0.5608, 0.6770, 0.6695,  ..., 0.4457, 0.4273, 0.4354],
#           [0.5720, 0.6631, 0.6506,  ..., 0.4739, 0.4516, 0.4463],
#           ...,
#           [0.5450, 0.6974, 0.6751,  ..., 0.5603, 0.5390, 0.5396],
#           [0.5144, 0.6191, 0.5780,  ..., 0.5438, 0.5352, 0.5423],
#           [0.5100, 0.5859, 0.5688,  ..., 0.4961, 0.4995, 0.5315]]],
#
#
#         [[[0.4709, 0.4878, 0.4979,  ..., 0.4130, 0.4040, 0.4340],
#           [0.4014, 0.4298, 0.4525,  ..., 0.3835, 0.3840, 0.4239],
#           [0.3882, 0.3894, 0.3881,  ..., 0.3671, 0.3615, 0.4288],
#           ...,
#           [0.3654, 0.4060, 0.4201,  ..., 0.4263, 0.4165, 0.4412],
#           [0.4155, 0.4571, 0.4784,  ..., 0.4711, 0.4693, 0.4890],
#           [0.4828, 0.5389, 0.5322,  ..., 0.5356, 0.5162, 0.5250]],
#
#          [[0.4169, 0.3821, 0.4093,  ..., 0.4491, 0.4708, 0.5208],
#           [0.4307, 0.3874, 0.4058,  ..., 0.4774, 0.4859, 0.5104],
#           [0.4274, 0.3897, 0.4096,  ..., 0.5086, 0.5047, 0.5160],
#           ...,
#           [0.5579, 0.6139, 0.6095,  ..., 0.5243, 0.5082, 0.4790],
#           [0.5749, 0.5911, 0.5621,  ..., 0.5022, 0.4929, 0.4660],
#           [0.5231, 0.5130, 0.4864,  ..., 0.5002, 0.4887, 0.4686]],
#
#          [[0.5311, 0.5694, 0.5585,  ..., 0.4676, 0.4580, 0.4444],
#           [0.5175, 0.5758, 0.5415,  ..., 0.4504, 0.4316, 0.4496],
#           [0.5181, 0.5826, 0.5459,  ..., 0.4672, 0.4466, 0.4571],
#           ...,
#           [0.5111, 0.6410, 0.6314,  ..., 0.5862, 0.5393, 0.5343],
#           [0.4941, 0.6212, 0.6268,  ..., 0.5767, 0.5520, 0.5400],
#           [0.5193, 0.5832, 0.5580,  ..., 0.5438, 0.5300, 0.5271]]],
#
#
#         [[[0.4368, 0.4846, 0.5293,  ..., 0.5263, 0.5097, 0.5059],
#           [0.3739, 0.4112, 0.4367,  ..., 0.4621, 0.4567, 0.3813],
#           [0.3480, 0.3203, 0.3075,  ..., 0.3024, 0.2677, 0.2509],
#           ...,
#           [0.3661, 0.5267, 0.6339,  ..., 0.3736, 0.3568, 0.4006],
#           [0.5360, 0.7499, 0.8444,  ..., 0.4488, 0.4279, 0.4467],
#           [0.6559, 0.8147, 0.8439,  ..., 0.5316, 0.5067, 0.5140]],
#
#          [[0.4113, 0.3829, 0.4134,  ..., 0.3877, 0.3441, 0.3926],
#           [0.3903, 0.3678, 0.3547,  ..., 0.3548, 0.3053, 0.3694],
#           [0.3840, 0.3745, 0.3460,  ..., 0.3331, 0.3116, 0.3874],
#           ...,
#           [0.6086, 0.7345, 0.8216,  ..., 0.5362, 0.5341, 0.4645],
#           [0.6247, 0.7264, 0.7698,  ..., 0.5063, 0.5138, 0.4561],
#           [0.6394, 0.6889, 0.6938,  ..., 0.4880, 0.4845, 0.4546]],
#
#          [[0.5514, 0.6695, 0.6866,  ..., 0.3690, 0.3165, 0.2889],
#           [0.5322, 0.6602, 0.6287,  ..., 0.4019, 0.2472, 0.2024],
#           [0.5401, 0.6338, 0.5865,  ..., 0.4500, 0.2774, 0.2497],
#           ...,
#           [0.5916, 0.8360, 0.7753,  ..., 0.6131, 0.5677, 0.5630],
#           [0.5171, 0.7692, 0.7246,  ..., 0.5782, 0.5587, 0.5512],
#           [0.5854, 0.7803, 0.7286,  ..., 0.5321, 0.5142, 0.5275]]],
#
#
#         ...,
#
#
#         [[[0.4833, 0.4918, 0.4889,  ..., 0.4181, 0.3983, 0.4239],
#           [0.4421, 0.4580, 0.4646,  ..., 0.3720, 0.3636, 0.4096],
#           [0.4323, 0.4367, 0.4356,  ..., 0.3387, 0.3254, 0.4123],
#           ...,
#           [0.4216, 0.4347, 0.4372,  ..., 0.3651, 0.3519, 0.4013],
#           [0.4509, 0.4675, 0.4744,  ..., 0.4287, 0.4122, 0.4538],
#           [0.4832, 0.5222, 0.5277,  ..., 0.5378, 0.5130, 0.5285]],
#
#          [[0.4484, 0.4325, 0.4466,  ..., 0.4210, 0.4637, 0.5261],
#           [0.4681, 0.4408, 0.4520,  ..., 0.4542, 0.4825, 0.5149],
#           [0.4663, 0.4415, 0.4556,  ..., 0.4993, 0.5068, 0.5275],
#           ...,
#           [0.5271, 0.5566, 0.5562,  ..., 0.5303, 0.5161, 0.4763],
#           [0.5316, 0.5358, 0.5267,  ..., 0.5175, 0.5041, 0.4632],
#           [0.5001, 0.4923, 0.4815,  ..., 0.5025, 0.4841, 0.4628]],
#
#          [[0.5197, 0.5409, 0.5374,  ..., 0.4508, 0.4355, 0.4226],
#           [0.5107, 0.5478, 0.5273,  ..., 0.4361, 0.4116, 0.4349],
#           [0.5092, 0.5556, 0.5311,  ..., 0.4586, 0.4369, 0.4514],
#           ...,
#           [0.5071, 0.5771, 0.5669,  ..., 0.6173, 0.5636, 0.5389],
#           [0.5066, 0.5703, 0.5617,  ..., 0.5892, 0.5624, 0.5367],
#           [0.5179, 0.5486, 0.5371,  ..., 0.5389, 0.5171, 0.5117]]],
#
#
#         [[[0.4850, 0.4891, 0.4854,  ..., 0.4579, 0.4529, 0.4665],
#           [0.4611, 0.4671, 0.4676,  ..., 0.4535, 0.4550, 0.4645],
#           [0.4506, 0.4507, 0.4495,  ..., 0.4488, 0.4477, 0.4681],
#           ...,
#           [0.3311, 0.3880, 0.4007,  ..., 0.4536, 0.4336, 0.4378],
#           [0.3874, 0.4471, 0.4718,  ..., 0.5214, 0.5087, 0.4993],
#           [0.4573, 0.5431, 0.5580,  ..., 0.5760, 0.5521, 0.5400]],
#
#          [[0.4684, 0.4624, 0.4711,  ..., 0.4730, 0.4849, 0.5125],
#           [0.4810, 0.4630, 0.4695,  ..., 0.4829, 0.4925, 0.5105],
#           [0.4797, 0.4644, 0.4729,  ..., 0.5045, 0.5083, 0.5143],
#           ...,
#           [0.5793, 0.6292, 0.6180,  ..., 0.5006, 0.4719, 0.4846],
#           [0.5810, 0.5872, 0.5598,  ..., 0.4726, 0.4420, 0.4576],
#           [0.4969, 0.4783, 0.4581,  ..., 0.5199, 0.4837, 0.4764]],
#
#          [[0.5132, 0.5311, 0.5276,  ..., 0.4937, 0.4826, 0.4757],
#           [0.5108, 0.5369, 0.5219,  ..., 0.4824, 0.4662, 0.4783],
#           [0.5113, 0.5415, 0.5232,  ..., 0.4891, 0.4738, 0.4813],
#           ...,
#           [0.5024, 0.6549, 0.6548,  ..., 0.5122, 0.4616, 0.4509],
#           [0.4803, 0.6396, 0.6529,  ..., 0.5329, 0.5124, 0.4856],
#           [0.5251, 0.6072, 0.5890,  ..., 0.4947, 0.4914, 0.4985]]],
#
#
#         [[[0.4795, 0.4866, 0.4828,  ..., 0.4479, 0.4359, 0.4527],
#           [0.4400, 0.4512, 0.4553,  ..., 0.4348, 0.4305, 0.4471],
#           [0.4256, 0.4264, 0.4268,  ..., 0.4245, 0.4143, 0.4500],
#           ...,
#           [0.3654, 0.4178, 0.4351,  ..., 0.3822, 0.3758, 0.4167],
#           [0.4241, 0.4850, 0.5137,  ..., 0.4590, 0.4512, 0.4779],
#           [0.4735, 0.5568, 0.5734,  ..., 0.5465, 0.5212, 0.5295]],
#
#          [[0.4508, 0.4376, 0.4520,  ..., 0.4552, 0.4757, 0.5179],
#           [0.4674, 0.4382, 0.4487,  ..., 0.4758, 0.4893, 0.5149],
#           [0.4664, 0.4415, 0.4542,  ..., 0.5119, 0.5138, 0.5229],
#           ...,
#           [0.5801, 0.6338, 0.6245,  ..., 0.4779, 0.4548, 0.4556],
#           [0.5918, 0.5973, 0.5681,  ..., 0.4635, 0.4459, 0.4433],
#           [0.5091, 0.4978, 0.4794,  ..., 0.4954, 0.4784, 0.4670]],
#
#          [[0.5213, 0.5461, 0.5401,  ..., 0.4826, 0.4687, 0.4606],
#           [0.5153, 0.5528, 0.5304,  ..., 0.4626, 0.4403, 0.4640],
#           [0.5150, 0.5591, 0.5321,  ..., 0.4696, 0.4502, 0.4678],
#           ...,
#           [0.5003, 0.6360, 0.6290,  ..., 0.5762, 0.5208, 0.5158],
#           [0.4731, 0.6234, 0.6332,  ..., 0.5769, 0.5535, 0.5345],
#           [0.5132, 0.5848, 0.5629,  ..., 0.5340, 0.5214, 0.5149]]]],
#        device='cuda:0', grad_fn=<DivBackward0>)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(xx[1].permute(1,2,0))

# %%
del xx, x, y, test_gen

# %%
torch.cuda.empty_cache()

# %%
from fastai.layers import Lambda

# %%
def AvgFlatten():
    "Takes the average of the input."
    return Lambda(lambda x: x.mean((1,2,3)))#.view(1))

# %% [markdown]
# ### Spade Discriminator

# %%
device_ = torch.device('cuda')

# %%
disc_nfs = [64,128,256,512]

USE_FM_LOSS = True
FM_WEIGHT = 10

class SpadeDiscriminator(nn.Module):
    def __init__(self, disc_nfs=disc_nfs):
        super(SpadeDiscriminator, self).__init__()
        self.layers = []
        
        self.conv0 = conv_layer(ni=4, nf=64, ks=4, stride=2, bias=True, norm_type=NormType.Spectral, use_activ=False)
        
        self.conv1 = conv_layer(ni=64, nf=128, ks=4, stride=2, bias=True, norm_type=NormType.Spectral, use_activ=False)
        self.in1 = nn.InstanceNorm2d(128)
        self.lrelu = nn.LeakyReLU(negative_slope=0.2, inplace=True)
        self.conv2 = conv_layer(ni=128, nf=256, ks=4, stride=2, bias=True, norm_type=NormType.Spectral, use_activ=False)
        self.in2 = nn.InstanceNorm2d(256)
        self.conv3 = conv_layer(ni=256, nf=512, ks=4, bias=True, norm_type=NormType.Spectral, use_activ=False)
        self.in3 = nn.InstanceNorm2d(512)         

        ### skipping a layer which seems to be a mistake in the paper.
        self.conv_final = conv_layer(ni=512, nf=1, ks=4, bias=True, norm_type=NormType.Spectral, use_activ=False) #hardcoded
#         self.layers.append(AvgFlatten())
#         self.disc = nn.Sequential(*self.layers)
        
    def forward(self, image, mask, down=2):
#         pdb.set_trace()
        final = torch.zeros(image.shape[0], dtype=image.dtype).to(device_)
    
        feat1s = []
        feat2s = []
        feat3s = []
        feat4s = []
        
        for i in range(down + 1):
            if i != 0:
                image = F.avg_pool2d(image, 2, 2) # downsampling
                mask = F.avg_pool2d(mask.type(image.dtype), 2, 2) # downsampling
            
#             print(image.shape, mask.shape)
            inp = torch.cat((image, mask.type(image.dtype)), dim=1)
                    
            feat1 = self.lrelu(self.conv0(inp))# will use these features later
            feat1s.append(feat1)
            
            feat2 = self.lrelu(self.in1(self.conv1(feat1)))
            feat2s.append(feat2)
            
            feat3 = self.lrelu(self.in2(self.conv2(feat2)))
            feat3s.append(feat3)
            
            feat4 = self.lrelu(self.in3(self.conv3(feat3)))            
            feat4s.append(feat4)
            
            final += self.conv_final(feat4).mean(dim=(1,2,3))  # adding all
        
        if USE_FM_LOSS:
            return final, [feat1s, feat2s, feat3s, feat4s]
        else:
            return final  ## taking mean/sum

# %% [markdown]
# ### test disc

# %%
test_disc = SpadeDiscriminator().cuda()

# %%
im = torch.randn(8,3,256,256).cuda()
mask = torch.Tensor(8,1,256,256).cuda()

# %%
test_disc(im, mask, down=2).shape
# Out:
# torch.Size([8, 3, 256, 256]) torch.Size([8, 1, 256, 256])
# torch.Size([8, 3, 128, 128]) torch.Size([8, 1, 128, 128])
# torch.Size([8, 3, 64, 64]) torch.Size([8, 1, 64, 64])
# torch.Size([8])

# %% [markdown]
# ### VGG module for Loss function

# %%
from torchvision.models import vgg16
from fastai.vision.learner import create_body

# %%
vgg16_backbone = create_body(vgg16, pretrained=True, body_fn=lambda x: list(x.children())[0]).to(device_)

# %%
vgg16_backbone
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
from fastai.callbacks.hooks import hook_outputs

# %%
save_feature_idxs = [6, 8, 13, 18, 22] #some random intermidiate features.

# %%
features = hook_outputs([vgg16_backbone[i] for i in save_feature_idxs])

# %%
class VGGLoss(nn.Module):
    def __init__(self, gpu_ids):
        super(VGGLoss, self).__init__()        
        self.vgg = Vgg19().cuda()
        self.save_feature_idxs = [6, 8, 13, 18, 22] #some random intermidiate features after ReLU.
        self.hooks = hook_outputs([vgg16_backbone[i] for i in save_feature_idxs])
        self.criterion = nn.L1Loss()
        self.weights = [1.0/32, 1.0/16, 1.0/8, 1.0/4, 1.0]        

    def forward(self, x, y):              
        x_vgg, y_vgg = self.vgg(x), self.vgg(y)  #use hooks here
        loss = 0
        for i in range(len(x_vgg)):
            loss += self.weights[i] * self.criterion(x_vgg[i], y_vgg[i].detach())        
        return loss

# %%
#test hooks
inp = torch.randn(8,3,256,256).cuda()

# %%
vgg16_backbone(inp).shape
# Out:
# torch.Size([8, 512, 8, 8])

# %%
len(features)
# Out:
# 5

# %%
features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-224628ecf868> in <module>
# ----> 1 features
#
# NameError: name 'features' is not defined

# %% [markdown]
# ###  Modify fastai GANLearner

# %%
class feature_matching_loss(nn.Module):
    def forward(self, real_feats, fake_feats):
        loss = 0
        for i in range(len(real_feats)):
            for feat_real, feat_fake in zip(real_feats[i], fake_feats[i]):
                loss += F.l1_loss(feat_real, feat_fake) / feat_real.shape[1]
        return loss

# %%
class GANModule(nn.Module):
    "Wrapper around a `generator` and a `critic` to create a GAN."
    def __init__(self, generator:nn.Module=None, critic:nn.Module=None, gen_mode:bool=False):
        super().__init__()
        self.gen_mode = gen_mode
        if generator: self.generator,self.critic = generator,critic

    def forward(self, *args):
#         pdb.set_trace()
        return self.generator(*args) if self.gen_mode else self.critic(*args)

    def switch(self, gen_mode:bool=None):
        "Put the model in generator mode if `gen_mode`, in critic mode otherwise."
        self.gen_mode = (not self.gen_mode) if gen_mode is None else gen_mode

# %%
class GANLoss(GANModule):
    "Wrapper around `loss_funcC` (for the critic) and `loss_funcG` (for the generator)."
    def __init__(self, loss_funcG, loss_funcC, gan_model:GANModule):
        super().__init__()
        self.loss_funcG,self.loss_funcC,self.gan_model = loss_funcG,loss_funcC,gan_model
        if USE_FM_LOSS:
            self.fm_loss = feature_matching_loss()

    def generator(self, output, target):
        "Evaluate the `output` with the critic then uses `self.loss_funcG` to combine it with `target`."
        fake_pred = self.gan_model.critic(output, target)[0] if USE_FM_LOSS else self.gan_model.critic(output, target)
        return self.loss_funcG(fake_pred)

    def critic(self, real_pred, input):
        "Create some `fake_pred` with the generator from `input` and compare them to `real_pred` in `self.loss_funcD`."
#         pdb.set_trace()
        if USE_FM_LOSS:
            real_pred, feats_real = real_pred
        fake = self.gan_model.generator(input.requires_grad_(False)).requires_grad_(True)
        fake_pred = self.gan_model.critic(fake, input.requires_grad_(False))
        if USE_FM_LOSS:
            fake_pred, feats_fake = fake_pred
            fm_loss = FM_WEIGHT * self.fm_loss(feats_real, feats_fake)
        return self.loss_funcC(real_pred, fake_pred) if not USE_FM_LOSS else self.loss_funcC(real_pred, fake_pred) + fm_loss

# %%
from fastai.basic_train import LearnerCallback
from fastai.basic_train import Learner
from fastai.callback import SmoothenValue
from functools import partial

def num_children(m:nn.Module)->int:
    "Get number of children modules in `m`."
    return len(list(m.children()))

def requires_grad(m:nn.Module, b=None):
    "If `b` is not set `requires_grad` on all params in `m`, else return `requires_grad` of first param."
    ps = list(m.parameters())
    if not ps: return None
    if b is None: return ps[0].requires_grad
    for p in ps: p.requires_grad=b


flatten_model = lambda m: sum(map(flatten_model,m.children()),[]) if num_children(m) else [m]

class GANTrainer(LearnerCallback):
    "Handles GAN Training."
    _order=-20
    def __init__(self, learn:Learner, switch_eval:bool=False, clip:float=None, beta:float=0.98, gen_first:bool=False,
                 show_img:bool=True):
#         pdb.set_trace()
        super().__init__(learn)
        self.switch_eval,self.clip,self.beta,self.gen_first,self.show_img = switch_eval,clip,beta,gen_first,show_img
        self.generator,self.critic = self.model.generator,self.model.critic

    def _set_trainable(self):
        train_model = self.generator if     self.gen_mode else self.critic
        loss_model  = self.generator if not self.gen_mode else self.critic
        requires_grad(train_model, True)
        requires_grad(loss_model, False)
        if self.switch_eval:
            train_model.train()
            loss_model.eval()

    def on_train_begin(self, **kwargs):
        "Create the optimizers for the generator and critic if necessary, initialize smootheners."
        if not getattr(self,'opt_gen',None):
            self.opt_gen = self.opt.new([nn.Sequential(*flatten_model(self.generator))])
        else: self.opt_gen.lr,self.opt_gen.wd = self.opt.lr,self.opt.wd
        if not getattr(self,'opt_critic',None):
            self.opt_critic = self.opt.new([nn.Sequential(*flatten_model(self.critic))])
        else: self.opt_critic.lr,self.opt_critic.wd = self.opt.lr,self.opt.wd
        self.gen_mode = self.gen_first
        self.switch(self.gen_mode)
        self.closses,self.glosses = [],[]
        self.smoothenerG,self.smoothenerC = SmoothenValue(self.beta),SmoothenValue(self.beta)
        self.recorder.no_val=True
        self.recorder.add_metric_names(['gen_loss', 'disc_loss'])
        self.imgs,self.titles = [],[]

    def on_train_end(self, **kwargs):
        "Switch in generator mode for showing results."
        self.switch(gen_mode=True)

    def on_batch_begin(self, last_input, last_target, **kwargs):
        "Clamp the weights with `self.clip` if it's not None, return the correct input."
        # set_trace()
        if self.clip is not None:
            for p in self.critic.parameters(): p.data.clamp_(-self.clip, self.clip)
        return ([last_input], last_input) if self.gen_mode else ([last_target, last_input], last_input)

    def on_backward_begin(self, last_loss, last_output, **kwargs):
        "Record `last_loss` in the proper list."
        last_loss = last_loss.detach().cpu()
        if self.gen_mode:
            self.smoothenerG.add_value(last_loss)
            self.glosses.append(self.smoothenerG.smooth)
            self.last_gen = last_output.detach().cpu()
        else:
            self.smoothenerC.add_value(last_loss)
            self.closses.append(self.smoothenerC.smooth)

    def on_epoch_begin(self, epoch, **kwargs):
        "Put the critic or the generator back to eval if necessary."
        self.switch(self.gen_mode)

    def on_epoch_end(self, pbar, epoch, **kwargs):
        "Put the various losses in the recorder and show a sample image."
        self.recorder.add_metrics([getattr(self.smoothenerG,'smooth',None),getattr(self.smoothenerC,'smooth',None)])
        if not hasattr(self, 'last_gen') or not self.show_img: return
        data = self.learn.data
        img = self.last_gen[0]
        norm = getattr(data,'norm',False)
        if norm and norm.keywords.get('do_y',False): img = data.denorm(img)
        img = data.train_ds.y.reconstruct(img)
        self.imgs.append(img)
        self.titles.append(f'Epoch {epoch}')
        pbar.show_imgs(self.imgs, self.titles)

    def switch(self, gen_mode:bool=None):
        "Switch the model, if `gen_mode` is provided, in the desired mode."
        self.gen_mode = (not self.gen_mode) if gen_mode is None else gen_mode
        self.opt.opt = self.opt_gen.opt if self.gen_mode else self.opt_critic.opt
        self._set_trainable()
        self.model.switch(gen_mode)
        self.loss_func.switch(gen_mode)

# %%
from dataclasses import dataclass
from fastai.basic_train import LearnerCallback

@dataclass
class FixedGANSwitcher(LearnerCallback):
    "Switcher to do `n_crit` iterations of the critic then `n_gen` iterations of the generator."
    n_crit=5
    n_gen=1

    def on_train_begin(self, **kwargs):
        "Initiate the iteration counts."
        self.n_c,self.n_g = 0,0

    def on_batch_end(self, iteration, **kwargs):
        "Switch the model if necessary."
        if self.learn.gan_trainer.gen_mode:
            self.n_g += 1
            n_iter,n_in,n_out = self.n_gen,self.n_c,self.n_g
        else:
            self.n_c += 1
            n_iter,n_in,n_out = self.n_crit,self.n_g,self.n_c
        target = n_iter if isinstance(n_iter, int) else n_iter(n_in)
        if target == n_out:
            self.learn.gan_trainer.switch()
            self.n_c,self.n_g = 0,0

# %%
from fastai.basic_train import Learner
from functools import partial
class GANLearner(Learner):
    "A `Learner` suitable for GANs."
    def __init__(self, data, generator:nn.Module, critic:nn.Module, gen_loss_func,
                 crit_loss_func, switcher=None, gen_first:bool=False, switch_eval:bool=True,
                 show_img:bool=True, clip:float=None, **kwargs):
        gan = GANModule(generator, critic)
        loss_func = GANLoss(gen_loss_func, crit_loss_func, gan)
        switcher = FixedGANSwitcher
        super().__init__(data, gan, loss_func=loss_func, callback_fns=[switcher], **kwargs)
        trainer = GANTrainer(self, clip=clip, switch_eval=switch_eval, show_img=show_img)
        self.gan_trainer = trainer
        self.callbacks.append(trainer)

# %% [markdown]
# ### Train

# %%
from fastai.layers import NoopLoss, Lambda

# %%
class disc_loss(nn.Module):
    def forward(self, real, fake):
#         print('disc loss')
        return F.relu(1 - real).mean() + F.relu(1 + fake).mean()

# %%
class gen_loss(nn.Module):
    def forward(self, fake):
#         print('gen loss')
        return -1 * fake.mean()

# %%
generator = SpadeGenerator()

# %%
discriminator = SpadeDiscriminator()

# %%
spadegan = GANLearner(data,
                      generator=generator,
                      critic=discriminator,
                      gen_loss_func=gen_loss(),
                      crit_loss_func=disc_loss()
                      )

# %%
spadegan.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
spadegan.recorder.plot()

# %%
spadegan.fit(epochs=100, lr=slice(4e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='43' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       43.00% [43/100 2:53:12<3:49:36]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>gen_loss</th>
#     <th>disc_loss</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.633619</th>
#     <th>1.271571</th>
#     <th>0.157800</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.034898</th>
#     <th>1.223113</th>
#     <th>0.866157</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.841200</th>
#     <th>0.550220</th>
#     <th>0.837587</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.677165</th>
#     <th>1.067828</th>
#     <th>0.751003</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.475347</th>
#     <th>0.704576</th>
#     <th>0.339105</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.743989</th>
#     <th>1.705160</th>
#     <th>0.130376</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.743396</th>
#     <th>3.688565</th>
#     <th>0.076532</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.899765</th>
#     <th>4.865761</th>
#     <th>0.097136</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>1.168007</th>
#     <th>5.735138</th>
#     <th>0.070828</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.844090</th>
#     <th>5.408994</th>
#     <th>0.043525</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.915862</th>
#     <th>5.333126</th>
#     <th>0.049944</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.715052</th>
#     <th>2.071799</th>
#     <th>0.700870</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.824946</th>
#     <th>0.694362</th>
#     <th>0.992941</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.596138</th>
#     <th>0.155362</th>
#     <th>0.662443</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.843852</th>
#     <th>0.829186</th>
#     <th>0.738747</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>1.275531</th>
#     <th>0.372319</th>
#     <th>1.381524</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.356257</th>
#     <th>-0.065032</th>
#     <th>0.639163</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.717790</th>
#     <th>0.666858</th>
#     <th>0.623456</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.476772</th>
#     <th>0.716767</th>
#     <th>0.375323</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.907904</th>
#     <th>0.830027</th>
#     <th>0.819308</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.919072</th>
#     <th>0.667301</th>
#     <th>0.915507</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.473847</th>
#     <th>-0.019220</th>
#     <th>0.464766</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.639644</th>
#     <th>0.246082</th>
#     <th>0.909936</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.626388</th>
#     <th>0.012310</th>
#     <th>0.854637</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.477456</th>
#     <th>-0.072845</th>
#     <th>0.659529</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.524657</th>
#     <th>0.214014</th>
#     <th>0.619349</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.486895</th>
#     <th>0.730897</th>
#     <th>0.467219</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.717270</th>
#     <th>1.938561</th>
#     <th>0.224498</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.493639</th>
#     <th>1.004481</th>
#     <th>0.465104</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.520346</th>
#     <th>0.953278</th>
#     <th>0.332270</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.536331</th>
#     <th>0.919194</th>
#     <th>0.488498</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.566703</th>
#     <th>1.235583</th>
#     <th>0.383560</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.428634</th>
#     <th>0.874749</th>
#     <th>0.392289</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.718622</th>
#     <th>1.819965</th>
#     <th>0.442535</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.606544</th>
#     <th>1.504116</th>
#     <th>0.544222</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.562246</th>
#     <th>1.340951</th>
#     <th>0.433620</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.510131</th>
#     <th>1.209599</th>
#     <th>0.392865</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.494418</th>
#     <th>1.255761</th>
#     <th>0.294947</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.614605</th>
#     <th>1.453532</th>
#     <th>0.376581</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.506654</th>
#     <th>1.457672</th>
#     <th>0.306361</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>0.543559</th>
#     <th>1.818593</th>
#     <th>0.237237</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>0.411194</th>
#     <th>1.349936</th>
#     <th>0.302266</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>0.508086</th>
#     <th>1.378563</th>
#     <th>0.335310</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='187' class='' max='485', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       38.56% [187/485 01:34<02:31 0.5876]
#     </div>

# %%
spadegan.save('fmloss100')

# %% [markdown]
# ### test generator

# %%
spadegan.load('goodloss100')
# Out:
# GANLearner(data=ImageDataBunch;
#
# Train: LabelList
# y: SpadeLabelList (3881 items)
# [Image (3, 400, 400), Image (3, 400, 400), Image (3, 400, 400), Image (3, 400, 400), Image (3, 400, 400)]...
# Path: D:\data\landcover\landcover\labels
# x: SpadeItemList (3881 items)
# [ImageSegment (1, 400, 400), ImageSegment (1, 400, 400), ImageSegment (1, 400, 400), ImageSegment (1, 400, 400), ImageSegment (1, 400, 400)]...
# Path: D:\data\landcover\landcover\labels;
#
# Valid: LabelList
# y: SpadeLabelList (0 items)
# []...
# Path: D:\data\landcover\landcover\labels
# x: SpadeItemList (0 items)
# []...
# Path: D:\data\landcover\landcover\labels;
#
# Test: None, model=GANModule(
#   (generator): SpadeGenerator(
#     (linear): Linear(in_features=256, out_features=16384, bias=True)
#     (spade_upsample_blocks): ModuleList(
#       (0): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#       (1): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#       (2): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#       (3): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#       (4): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#       (5): ModuleList(
#         (0): SpadeResBlock(
#           (spade_bn0): SpadeBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv0): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_bn1): SpadeBN(
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (spade_skip): SpadeBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#             (conv0): Sequential(
#               (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#             (conv2): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace)
#             )
#           )
#           (conv_skip): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (conv_final): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (critic): SpadeDiscriminator(
#     (conv0): Sequential(
#       (0): Conv2d(4, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (conv1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (in1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace)
#     (conv2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (in2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (conv3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     )
#     (in3): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (conv_final): Sequential(
#       (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=GANLoss(
#   (loss_funcG): gen_loss()
#   (loss_funcC): disc_loss()
#   (gan_model): GANModule(
#     (generator): SpadeGenerator(
#       (linear): Linear(in_features=256, out_features=16384, bias=True)
#       (spade_upsample_blocks): ModuleList(
#         (0): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#         (1): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#         (2): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#         (3): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#         (4): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#         (5): ModuleList(
#           (0): SpadeResBlock(
#             (spade_bn0): SpadeBN(
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv0): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_bn1): SpadeBN(
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (spade_skip): SpadeBN(
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#               (conv0): Sequential(
#                 (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#               (conv2): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): ReLU(inplace)
#               )
#             )
#             (conv_skip): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#           )
#           (1): PixelShuffle_ICNR(
#             (conv): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (shuf): PixelShuffle(upscale_factor=2)
#             (pad): ReplicationPad2d((1, 0, 1, 0))
#             (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#             (relu): ReLU(inplace)
#           )
#         )
#       )
#       (conv_final): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (critic): SpadeDiscriminator(
#       (conv0): Sequential(
#         (0): Conv2d(4, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (conv1): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (in1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace)
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (in2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (conv3): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#       (in3): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (conv_final): Sequential(
#         (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# ), metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('D:/data/landcover/landcover/labels'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>, <class '__main__.FixedGANSwitcher'>], callbacks=[GANTrainer()], layer_groups=[Sequential(
#   (0): Linear(in_features=256, out_features=16384, bias=True)
#   (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (2): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace)
#   (4): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU(inplace)
#   (6): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace)
#   (8): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (10): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace)
#   (16): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (17): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (18): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (19): ReLU(inplace)
#   (20): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (21): ReLU(inplace)
#   (22): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (23): ReLU(inplace)
#   (24): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (26): PixelShuffle(upscale_factor=2)
#   (27): ReplicationPad2d((1, 0, 1, 0))
#   (28): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (29): ReLU(inplace)
#   (30): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (31): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (32): ReLU(inplace)
#   (33): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (34): ReLU(inplace)
#   (35): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (36): ReLU(inplace)
#   (37): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (38): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (39): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (40): ReLU(inplace)
#   (41): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (42): ReLU(inplace)
#   (43): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (44): ReLU(inplace)
#   (45): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (46): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (47): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (48): ReLU(inplace)
#   (49): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (50): ReLU(inplace)
#   (51): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (52): ReLU(inplace)
#   (53): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (54): Conv2d(1024, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (55): PixelShuffle(upscale_factor=2)
#   (56): ReplicationPad2d((1, 0, 1, 0))
#   (57): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (58): ReLU(inplace)
#   (59): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (60): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (61): ReLU(inplace)
#   (62): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (63): ReLU(inplace)
#   (64): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (65): ReLU(inplace)
#   (66): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (67): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (68): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (69): ReLU(inplace)
#   (70): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (71): ReLU(inplace)
#   (72): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (73): ReLU(inplace)
#   (74): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (75): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (76): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (77): ReLU(inplace)
#   (78): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (79): ReLU(inplace)
#   (80): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (81): ReLU(inplace)
#   (82): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (83): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (84): PixelShuffle(upscale_factor=2)
#   (85): ReplicationPad2d((1, 0, 1, 0))
#   (86): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (87): ReLU(inplace)
#   (88): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (89): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (90): ReLU(inplace)
#   (91): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (92): ReLU(inplace)
#   (93): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (94): ReLU(inplace)
#   (95): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (96): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (97): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (98): ReLU(inplace)
#   (99): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (100): ReLU(inplace)
#   (101): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (102): ReLU(inplace)
#   (103): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (104): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (105): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (106): ReLU(inplace)
#   (107): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (108): ReLU(inplace)
#   (109): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (110): ReLU(inplace)
#   (111): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (112): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (113): PixelShuffle(upscale_factor=2)
#   (114): ReplicationPad2d((1, 0, 1, 0))
#   (115): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (116): ReLU(inplace)
#   (117): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (118): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (119): ReLU(inplace)
#   (120): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (121): ReLU(inplace)
#   (122): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (123): ReLU(inplace)
#   (124): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (125): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (126): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (127): ReLU(inplace)
#   (128): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (129): ReLU(inplace)
#   (130): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (131): ReLU(inplace)
#   (132): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (133): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (134): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (135): ReLU(inplace)
#   (136): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (137): ReLU(inplace)
#   (138): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (139): ReLU(inplace)
#   (140): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (141): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#   (142): PixelShuffle(upscale_factor=2)
#   (143): ReplicationPad2d((1, 0, 1, 0))
#   (144): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (145): ReLU(inplace)
#   (146): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (147): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (148): ReLU(inplace)
#   (149): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (150): ReLU(inplace)
#   (151): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (152): ReLU(inplace)
#   (153): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (154): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (155): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (156): ReLU(inplace)
#   (157): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (158): ReLU(inplace)
#   (159): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (160): ReLU(inplace)
#   (161): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (162): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (163): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (164): ReLU(inplace)
#   (165): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (166): ReLU(inplace)
#   (167): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (168): ReLU(inplace)
#   (169): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (170): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#   (171): PixelShuffle(upscale_factor=2)
#   (172): ReplicationPad2d((1, 0, 1, 0))
#   (173): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (174): ReLU(inplace)
#   (175): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (176): Conv2d(4, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (177): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (178): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (179): LeakyReLU(negative_slope=0.2, inplace)
#   (180): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (181): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (182): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#   (183): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (184): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
# )])

# %%
spadegan.gan_trainer.switch(gen_mode=True)

# %%
x, y = next(iter(data.train_dl))

# %%
from fastai.vision import open_mask, ImageSegment

# %%
x.shape
# Out:
# torch.Size([8, 1, 256, 256])

# %%
idx = 0

# %%
Image(y[idx])
# Out:
# Image (3, 256, 256)

# %%
ImageSegment(x[idx])
# Out:
# ImageSegment (1, 256, 256)

# %%
xx = spadegan.gan_trainer.generator(x)

# %%
Image(xx[idx].detach())
# Out:
# Image (3, 256, 256)
